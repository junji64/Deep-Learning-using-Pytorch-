# %% [markdown]
# # Linear Model

# %%
import matplotlib.pyplot as plt

x = [1,  2,  3,  4,   5,   6,   7,   8]
y = [2,3.2,6.3,8.2,10.5,11.5,14.5,15.5]

plt.scatter(x, y, label="data", color="b", marker="*")
plt.xlabel('x')
plt.ylabel('y')
plt.title('data')
plt.legend()
plt.grid()
plt.show()

# %% [markdown]
# ### Forward Model
# $$ \hat{y} = w * x $$

# %%
w = 2.0  # a random guess (i.e. random value)

# a lineadr model for the forward pass
def forward(x):
    return x * w

forward(5)
# Out:
# 10.0

# %% [markdown]
# ### Loss ( Error )
# $$ loss = ( \hat{y} - y )^2 $$
# $$ loss = ( w * x - y ) ^2 $$

# %%
# Loss function
def loss(x, y):
    y_pred = forward(x)
    return (y_pred - y) * (y_pred - y)

loss(5, 8)
# Out:
# 4.0

# %% [markdown]
# ### Compute losses for a range of w

# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.array([1,2,3,4,5,6,7,8])
y = np.array([2,3.2,6.3,8.2,10.5,11.5,14.5,15.5])
y1 = 2.5*x    # when w = 2.5
y2 = 2*x      # when w = 2.
y3 = 1.5*x    # when w = 1.5

plt.scatter(x, y, label="data", color="b", marker="*")
plt.plot(x,y1, x,y2, x,y3)
plt.xlabel('x')
plt.ylabel('y')
plt.title('title')
plt.legend()
plt.show()

# %%
import numpy as np

x_data = [1,2,3,4,5,6,7,8]
y = np.array([2,3.2,6.3,8.2,10.5,11.5,14.5,15.5])

for w in np.arange(0., 4.1, 0.1):
    loss_sum = 0
    for x_val, y_val in zip(x_data, y_data):
        y_pred_val = forward(x_val)
        l = loss(x_val, y_val)
        loss_sum += l
        # print("\t", x_val, y_val, y_pred_val, l)
        
    if (10*w/0.5)%10 == 0:
        print("w =", w, "  MSE =", loss_sum / 8)
# Out:
# w = 0.0   MSE = 100.19375
# w = 0.5   MSE = 56.05625
# w = 1.0   MSE = 24.66875
# w = 1.5   MSE = 6.03125
# w = 2.0   MSE = 0.14375
# w = 2.5   MSE = 7.0062500000000005
# w = 3.0   MSE = 26.61875
# w = 3.5   MSE = 58.98125
# w = 4.0   MSE = 104.09375

# %%
import matplotlib.pyplot as plt

w_list = []
mse_list = []

for w in np.arange(0.0, 4.1, 0.1):
    loss_sum = 0
    for x, y in zip(x_data, y_data):
        loss_val = loss(x,y)
        loss_sum += loss_val
    w_list.append(w)
    mse_list.append(loss_sum / 3)
    
plt.plot(w_list, mse_list)
plt.xlabel('w')
plt.ylabel('Loss')
plt.show()

# %% [markdown]
# ## A complete source code for the loss of linear model

# %%
import numpy as np
import matplotlib.pyplot as plt

x_data = [1,  2,  3,  4,   5,   6,   7,   8]
y_data = [2,3.2,6.3,8.2,10.5,11.5,14.5,15.5]

# a lineadr model for the forward pass
def forward(x):
    return x * w

# Loss function
def loss(x, y):
    y_pred = forward(x)
    return (y_pred - y) * (y_pred - y)

w_list = []
mse_list = []

for w in np.arange(0.0, 4.1, 0.1):
    loss_sum = 0
    for x, y in zip(x_data, y_data):
        loss_val = loss(x,y)
        loss_sum += loss_val
    w_list.append(w)
    mse_list.append(loss_sum / 8)
    
plt.plot(w_list, mse_list)
plt.xlabel('w')
plt.ylabel('Loss')
plt.show()

# %% [markdown]
# ## Exercise 2.1  ( in class )
# - Any other interesting linear prediction problem
#  - Size of house vs Price
# - Find some datasets for linear prediction
#  - Draw the loss graph for the dataset
